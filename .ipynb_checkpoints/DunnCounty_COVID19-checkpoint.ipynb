# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import dates
from datetime import date
from IPython.display import display, Markdown
# %matplotlib inline

# %%
# This is the data for all of Wisconsin.
url = "https://opendata.arcgis.com/datasets/b913e9591eae4912b33dc5b4e88646c5_10.csv"
data = pd.read_csv(url, parse_dates=['LoadDttm'])

# %%
dc = data.groupby('NAME').get_group('Dunn').sort_values(by='LoadDttm') # Select the date for Dunn County from the full data.
PNi = dc.columns.get_loc("POS_NEW")
dc['7_DAY'] = dc.iloc[:,PNi].rolling(window=7).mean() # Calculates the rolling 7-day average of new cases.

# %% [markdown]
# ## Cummulative number of cases in Dunn County, WI.

# %%
dc.plot(x='LoadDttm',y='POSITIVE',color='red',grid='True',figsize=(12,6));

# %% [markdown]
# ## Rolling 7-day average of new cases.

# %%
dc.plot(kind='line',x='LoadDttm',y='7_DAY',color='blue',grid='True',figsize=(12,6));

# %%
display(Markdown('Last updated: ' + date.today().strftime("%B %d, %Y")))
# Out:
# Last updated: July 30, 2020

# %% [markdown]
# Data source: [Wisconsin Department of Health Services](https://data.dhsgis.wi.gov/datasets/covid-19-historical-data-table/)
